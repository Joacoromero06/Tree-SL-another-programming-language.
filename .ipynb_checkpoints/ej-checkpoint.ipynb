# %%
lista = [1,2,3,4,5]

# %%
for x in lista:
    print(x)
print(f"value of x after for: {x}")
# Out:
# 1
# 2
# 3
# 4
# 5
# value of x after for: 5

# %%
band1 = True
band2 = True
i = 0; j = 0; n = 10
M = [ [x*i for x in lista + [6,7,8,9,10]] for i in range (n) ]
#print (M)
while i < n:
    f_i = M[i]
    while j < n: 
        x_ij = f_i[j]
        if x_ij == 1:
            print("continue x_ij = 1")
            continue
        if x_ij == 2:
            break
            #return
        print ("j++")
        j += 1 
    print ("i++"); i += 1; j = 0;
# Out:
# j++
# j++
# j++
# j++
# j++
# j++
# j++
# j++
# j++
# j++
# i++
# i++
# i++
# i++
# i++
# i++
# i++
# i++
# i++
# i++

# %%
x = 3
lista = [1,2,3,4,5]
while x > 0:
    for x in lista:
        if x == x:
            print(f"break statement, value of x: {x}")
            break
        print(x) 
    x = x-1
print(f"value of x after algorithm: {x}")
